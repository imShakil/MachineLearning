# %%
#plotting lab test

import matplotlib.pyplot as plt


X = range(100)
Y = [value ** 2 for value in X]

plt.plot(X, Y)
plt.show()

# %%
# plotting curved

import math

T = range(100)
X = [(2 * math.pi * t)/ len(T) for t in T]
Y = [math.sin(x) for x in X]
plt.plot(X, Y)
plt.show()

# %%
# plotting in some style

X = [1, 2, 3, 4]
Y = [20, 21, 20.5, 20.8]
plt.plot(X, Y, linestyle="dashed", marker="o", color="green")

# %%
# plotting mupltiples curved
import numpy as np

X = np.linspace(0, 2*np.pi, 100)
Ya = np.sin(X)
Yb = np.cos(X)

plt.plot(X, Ya, marker="o")
plt.plot(X, Yb, marker="o")
plt.show()

# %%
# plotting from a file

X, Y = [], []

for line in open("original.txt", "r"):
    values = [float(s) for s in line.split()]
    X.append(values[0])
    Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
#scatter plot

data = np.random.rand(120, 2) # generated random numbers upto 124, with 2 dimensions

plt.scatter(data[:,0], data[:,1])

# %%
#Scatter plot lab test

import matplotlib

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

raw_data = {'first_name': ['Mike', 'Brad', 'Chan', 'Dee', 'Stan'], 
        'last_name': ['Miller', 'Smith', 'Man', 'Milner', 'Chin'], 
        'female': [0, 1, 1, 0, 1],
        'age': [42, 52, 36, 24, 73], 
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'female', 'preTestScore', 'postTestScore'])
df

plt.scatter(df.preTestScore, df.postTestScore, s=200, c=df.female)
plt.show()

# %%
# plotting bar charts

data = list(range(5, 30, 5))


plt.barh(range(len(data)), data) # horizontal
plt.show()

plt.bar(range(len(data)), data, width=1.) # vertical
plt.show()

# %%
# multiple colored bar charts

data = [[5, 10, 20, 15, 25],
       [1, 30, 10, 25, 5],
       [4, 20, 30, 10, 15]]

X = np.arange(5)

plt.bar(X + .00, data[0], color='b', width=.25)
plt.bar(X + .25, data[1], color='g', width=.25)
plt.bar(X + .50, data[2], color='r', width=.25)

plt.show()

# %%
# multiple stacked bars

A = np.array([5., 30., 45., 22.]) 
B = np.array([5., 25., 50., 20.]) 
C = np.array([3.,  4.,  12.,  11.])

X = np.arange(4)

plt.bar(X, A, color='b')
plt.bar(X, B, color='g')
plt.bar(X, C, color='r')

plt.show()

# %%
# plotting pie chart

data = [ (i+1)* 5 for i in range(10)]

print(data)

plt.pie(data)
plt.show()
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
# plotting histogram

data = np.random.randn(1000)

plt.hist(data, bins = 20, width=.25)
plt.show()

# %%
# lab plotting a histogram

testscores= [62, 50,90, 55, 92, 80, 84, 88, 98, 54, 72, 60,68,
             94, 77, 86, 92, 32, 65, 86, 95]

bins=[30,40,50,60,70,80,90,100]

plt.hist(testscores, bins, histtype='bar', rwidth=.8, cumulative=True)
plt.show()

# %%
#plotting boxplot

data = np.random.randn(100)

plt.boxplot(data)
plt.show()

# %%
# lab plotting boxplot

data = np.random.randn(100, 5)

plt.boxplot(data)
plt.show()

# %%
# plotting triangulations

import matplotlib.tri as tri

data = np.random.rand(100, 2)
triangles = tri.Triangulation(data[:,0], data[:,1])

plt.triplot(triangles)
plt.show()

# %% [markdown]
# ### <center>Adding styles and colors</center>

# %%
def pdf(x, mu, sig):
    a = 1 / (sig * np.sqrt(2. * np.pi))
    b = -1 / (2. * sig ** 2)
    return a * np.exp(b * (x-mu) ** 2)

x = np.linspace(-6, 6, 1000)

for i in range(5):
    samples = np.random.standard_normal(50)
    mu, sig = np.mean(samples), np.std(samples)
    plt.plot(x, pdf(x, mu, sig), color='k')

plt.plot(x, pdf(x, 0., 1.), color='k')
plt.show()

# %%
# lab : scatter plot grey scale from file

label_set = (  b'Iris-setosa',  b'Iris-versicolor',  b'Iris-virginica', )

def read_label(label):
    return label_set.index(label)

data = np.loadtxt('iris.txt',                             
                  delimiter = ',',                             
                  converters = { 4 : read_label })
color_set = ('r', 'b', 'c') 
color_list = [color_set[int(label)] 
              for label in data[:,4]]
plt.scatter(data[:,0], data[:,1], color = color_list) 
plt.show()

# %%
# Edge color parameter

data = np.random.standard_normal((100, 2))

plt.scatter(data[:, 0], data[:, 1], color='.90', edgecolor='.10')
plt.show()

# %%
# Adding color to bar charts

women_pop = np.array(([55., 65., 25., 32.]))
men_pop = np.array(([45., 35., 75., 68.]))

X = np.arange(4)
plt.barh(X, women_pop, color='.40')
plt.barh(X, -men_pop, color='.60')
plt.show()

# %%
# lab : bar chart on dependent values

datas = np.random.randint(99, size=50)

color_set = ('.00', '.25', '.50', '.75')
color_list = [color_set[len(color_set) * val // 100 ] for val in datas]
X = np.arange(len(datas))

plt.bar(X, datas, color=color_list)
plt.show()

# changing color set

color_set = ('r', 'g', 'b', 'm')

color_list = [color_set[len(color_set) * val // 100] for val in datas]

plt.bar(X, datas, color=color_list)
plt.show()

# %%
# lab : controlling pattern and fill in chart

N = 8
A = np.random.random(N)
B = np.random.random(N)
X = np.arange(N)

plt.bar(X, A, color='.25', hatch='x')
plt.bar(X, A+B, bottom=A, color='.75', hatch='/')
plt.show()

# %%
# controlling marker size

A = np.random.standard_normal((100, 2))
A += np.array((-1, -1))

B = np.random.standard_normal((100, 2))
B += np.array((-1, -1))

plt.scatter(B[:, 0], B[:, 1], color='.75', s=100)
plt.scatter(A[:, 0], A[:, 1], color='.25', s=100)
plt.show()

# %%
# controlling marker frequency

X = np.linspace(-6, 6, 1024)

Y1 = np.sinc(X)
Y2 = Y1+1

plt.plot(X, Y1, marker='o', markevery=25)
plt.plot(X, Y2, marker='o', markevery=50)
plt.show()

# %%
# creating custom marker

x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y, s, c='g', alpha=.4, marker=r'$\clubsuit$', label='DUCK')
plt.xlabel('X value')
plt.ylabel('Y value')
plt.legend(loc=2)
plt.show()

# %%
# list as input for size parameter

M = np.random.standard_normal((1000, 2))
R = np.sum(M ** 2, axis=1)

plt.scatter(M[:, 0], M[:, 1], c='b', marker='o', s=10*R)
plt.show()

# %%
#changing background color schemes in graph

import matplotlib as mpl

mpl.rc('lines', linewidth=2.)
mpl.rc('text', color='w')
mpl.rc('xtick', color='w')
mpl.rc('ytick', color='w')
mpl.rc('axes', facecolor='k', edgecolor='w')
mpl.rc('figure', facecolor='k', edgecolor='w')

X = np.linspace(0, 7, 1024)

plt.plot(X, np.sin(X))
plt.plot(X, np.cos(X))
plt.show()

# %%
# saving figure as png/jpeg/pdf

X = np.linspace(-10, 10, 1024)
Y = np.sinc(X)

plt.plot(X, Y)
plt.savefig('fig.pdf')

# %% [markdown]
# ### <center>Annotations </center>

# %%
# set title of a graph

X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)

plt.plot(X, Y)
plt.title('A ploynomial Equation')
plt.show()

# %%
## Showing text anywhere in plot

plt.plot(X, Y)
plt.title('A ploynomial Equation')
plt.text(-.3, .3, 'nice slope')
plt.show()

# %%
# Adding an arrow to plot

plt.annotate('Low Point', ha='center', va='bottom', xytext=(-1.5, 3.), xy=(.75, -2.7),
            arrowprops={'shrink': .05})

plt.plot(X, Y)
plt.title("A polynomial Equation")
plt.show()

# %%
## Adding grid to plot

plt.plot(X, Y)
plt.grid(True, lw=2, ls='--')
plt.show()

# %%
# adding ticks on plot
import matplotlib.ticker as ticker

name_list = ("Shakil", "Shamim", "Mehedi", "Raju", "Akib")
height_list = [5. + (np.random.randint(2, 9)*1.0 / 10.0) for i in range(5)]
pos_list = np.arange(len(name_list))

ax = plt.axes()
ax.xaxis.set_major_locator(ticker.FixedLocator((pos_list))) 
ax.xaxis.set_major_formatter(ticker.FixedFormatter((name_list)))

plt.bar(pos_list, height_list, align='center')
plt.show()

# another way to ticks in x axis

plt.bar(pos_list, height_list, color='r', align='center')
plt.xticks(pos_list, name_list)
plt.show()

# %% [markdown]
# ## <center>Seaborn</center>

# %%
import seaborn as sns

data = np.random.normal(size=(20, 6)) + np.arange(6) / 2

sns.set_style("whitegrid")
sns.boxplot(data=data)
plt.title("whitegrid")
plt.show()

sns.set_style("darkgrid")
sns.boxplot(data=data);
plt.title("darkgrid")
plt.show()

sns.set_style("white")
sns.boxplot(data=data);
plt.title("white")
plt.show()

sns.set_style("dark")
sns.boxplot(data=data);
plt.title("dark")
plt.show()

sns.set_style("ticks")
sns.boxplot(data=data);
plt.title("ticks")
plt.show()

# %%
# creating factorplot

titanic = sns.load_dataset("titanic")
print(titanic.columns)
print(titanic.dtypes)
print(titanic.shape)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object
# (891, 15)

# %%
g = sns.catplot("class", "survived", "sex", data=titanic, kind="bar", palette="muted", legend=True)

plt.title("Titanic Survived plot")
plt.show()

# %%
# creating simple colormap

from matplotlib.colors import ListedColormap as lcmap


N = 500  # just a varable

c_palette = sns.color_palette("muted", n_colors=5)
cmap = lcmap(sns.color_palette(c_palette).as_hex())

data1 = np.random.randn(N)
data2 = np.random.randn(N)

colors = np.random.randint(0, 5, N)

plt.scatter(data1, data2, c=colors, cmap=cmap)
plt.colorbar()
plt.show()

# %%
# Scaling seaborn plots

sns.set()

sns.set_context("notebook")  # 4 options(paper, notebook, talk, poster)

data = sns.load_dataset("iris")

sns.swarmplot(x="species", y="petal_length", data=data)
plt.show()

# %%
# controlling font size in context

sns.set_context("paper", font_scale=6, rc={"font.size":8, "axes.labelsize": 5})
sns.swarmplot(x="species", y="petal_length", data=data)
plt.show()

# %%
# lab : figure label functions

sns.set()
sns.catplot("class", "survived", "sex", data=titanic, kind="bar", height=7, palette="muted", legend="True")
plt.show()

# %%
# rotate text on a seaborn plot

x = 10 ** np.arange(1, 10)
y = x * 2
data = pd.DataFrame(data={'x': x, 'y': y})
grid = sns.lmplot('x', 'y', data, height=7, truncate=True, scatter_kws={"s": 100})
grid.set_xticklabels(rotation=30)
plt.show()
